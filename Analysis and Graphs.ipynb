# %% [markdown]
# ffp_hr (Human Rights) highly correlates with:\
#
# 0.92 ffp_sl (State Legitimacy)\
# fh_fog (Functioning of Government) -0.91\
# 0.9 fhp_score5 (Freedom of Press:Score)\
# -0.89 bti_cr (Civil Rights)\
# -0.89 iiag_phr (Participation and Human Rights)\
# fh_pr (Political Rights) 0.88 (1-most free, 7-least free)\
# -0.87 bti_ds (Democracy Status)\
# -0.87 bti_rol (Rule of Law)\
# -0.83 iiag_srol (Safety and Rule of Law)\
# 0.81 fhn_fotnsc (Freedom of Net:Score)\
# bti_pdi (Performance of Democratic Institutions) -0.81\
# -0.8 bti_ij (Independent Judiciary)\
# -0.8 sgi_so (Policy Performance: Social Policies - Overall)\
# bti_pp (Political Participation) -0.79\
# vdem_gender (Women political empowerment index) -0.79\
# -0.79 bti_cdi (Commitment to Democratic Institutions)\
# 0.79 rsf_pfi (Press freedom Index)\
# -0.78 ht_regtype (Regime Type)\
# -0.78 bti_mes (Market Economy Status)\
# cspf_sfi (State Fragility Index) 0.78\
# vdem_corr (Political Corruption Index) 0.78\
# wbgi_gee (Government Effectiveness) -0.77\
# 0.77 gd_ptsa (Political Terror Scale - Amnesty International)\
# -0.77 bti_aar (Association/Assembly Rights)\
# -0.77 hf_prights (Property Rights)\
# -0.77 bbi_ffe (Free and fair Elections)\
# -0.77 bbi_sop (Separation of Powers)\
# -0.76 sgi_qdep (Quality of Democracy: Electoral Process)\
# -0.75 bti_wr (Welfare Regime)\
# bti_eo (Equal Opportunity) -0.74\
# gpi_gpi (Global Peace Index) 0.74\
# ess_happy (Subjective Happiness) -0.74\
# 0.74 wvs_imprel (Important in Life: Religion)\
# -0.74 van_index (Index of Democratization)\
# wbgi_pve (Political Stability and Absence of Terrorism) -0.73\
# bti_su (Sustainability) -0.73\
# -0.73 bbi_ps (Party System)\
# -0.73 bti_foe (Freedom of Expression)\
# -0.73 ciri_polpris (Political Imprisonment)\
# -0.73 bti_foe (Freedom of Expression)\
# -0.73 vdem_mecorrpt (Media corrupt)\
# -0.72 ess_trpolice (Trust in Police)\
# -0.71 bti_ssn (Social Safety Nets)\
# -0.7 iiag_ns (National Security)

# %%
import pandas as pd
data = pd.read_csv('/Users/victoria/Project-Week6-HumanRights/qog_bas_cs_jan20.csv')
correlated = data[['cname', 'ffp_hr', 'ffp_sl', 'fh_fog', 'fhp_score5', 'bti_cr', 'iiag_phr', 'fh_pr', 'bti_ds', 'bti_rol', 'iiag_srol', 'fhn_fotnsc', 'bti_pdi', 'bti_ij', 'sgi_so', 'bti_pp', 'vdem_gender', 'bti_cdi', 'rsf_pfi', 'ht_regtype', 'bti_mes', 'cspf_sfi', 'vdem_corr', 'wbgi_gee', 'gd_ptsa', 'bti_aar', 'hf_prights', 'bti_ffe', 'bti_sop', 'sgi_qdep', 'bti_wr', 'bti_eo', 'gpi_gpi', 'ess_happy', 'wvs_imprel', 'van_index', 'wbgi_pve', 'bti_su', 'bti_ps', 'bti_foe', 'ciri_polpris', 'bti_foe', 'vdem_mecorrpt', 'ess_trpolice', 'bti_ssn', 'iiag_ns']]

# %%
correlated
# Out:
#            cname  ffp_hr  ffp_sl  fh_fog  fhp_score5  bti_cr   iiag_phr  \
# 0    Afghanistan     8.5     9.1       2          60     2.0        NaN
# 1        Albania     4.8     5.7       7          51     8.0        NaN
# 2        Algeria     6.6     6.9       3          65     5.0  41.599998
# 3        Andorra     NaN     NaN      12          15     NaN        NaN
# 4         Angola     7.3     8.6       1          73     4.0  37.700001
# ..           ...     ...     ...     ...         ...     ...        ...
# 189   Uzbekistan     9.2     9.5       0          95     2.0        NaN
# 190    Venezuela     8.9     8.5       0          81     4.0        NaN
# 191        Samoa     4.1     5.5       9          29     NaN        NaN
# 192        Yemen     9.7     9.7       1          85     1.0        NaN
# 193       Zambia     7.4     7.7       6          63     5.0  58.500000
#
#      fh_pr    bti_ds  bti_rol  ...  wbgi_pve  bti_su  bti_ps  bti_foe  \
# ...

# %%
correlated[(correlated['cname']=='Korea, North')]
# Out:
#            cname  ffp_hr  ffp_sl  fh_fog  fhp_score5  bti_cr  iiag_phr  fh_pr  \
# 89  Korea, North     9.4    10.0       0          98     1.0       NaN      7
#
#     bti_ds  bti_rol  ...  wbgi_pve  bti_su  bti_ps  bti_foe  ciri_polpris  \
# 89     2.6      1.0  ...    -0.681     2.0     1.0      1.0             0
#
#     bti_foe  vdem_mecorrpt  ess_trpolice  bti_ssn  iiag_ns
# 89      1.0          0.036           NaN      2.0      NaN
#
# [1 rows x 46 columns]

# %%
correlated.to_csv('/Users/victoria/Project-Week6-HumanRights/correlated.csv')

# %%
plt.figure(figsize=(40,40))
matrix = np.triu(correlated.corr())
sns.heatmap(correlated.corr(), annot=True, mask=matrix)
# Out:
# <AxesSubplot:>

# %%
time_data = pd.read_csv('/Users/victoria/Project-Week6-HumanRights/qog_bas_ts_jan20.csv')
nl = time_data[(time_data['cname']=='Netherlands')]

# %%
nl[['year','ffp_hr']].plot(x='year', y='ffp_hr', label='HRI', title='Netherlands');

# %%
correlated['ciri_polpris'].plot.hist(grid=True, color='#607c8e');
plt.title('Political Imprisonment');

# %%
correlated[(correlated['fhp_score5']==98)]
# Out:
#             cname  ffp_hr  ffp_sl  fh_fog  fhp_score5  bti_cr  iiag_phr  \
# 89   Korea, North     9.4    10.0       0          98     1.0       NaN
# 178  Turkmenistan     8.7     9.7       0          98     2.0       NaN
#
#      fh_pr  bti_ds  bti_rol  ...  wbgi_pve  bti_su  bti_ps  bti_foe  \
# 89       7    2.60     1.00  ... -0.680761     2.0     1.0      1.0
# 178      7    2.85     2.25  ... -0.189693     3.5     2.0      1.0
#
#      ciri_polpris  bti_foe  vdem_mecorrpt  ess_trpolice  bti_ssn  iiag_ns
# 89              0      1.0          0.036           NaN      2.0      NaN
# 178             0      1.0          0.103           NaN      4.0      NaN
#
# [2 rows x 46 columns]

# %%
correlated = correlated.round(3)

# %%
correlated
# Out:
#            cname  ffp_hr  ffp_sl  fh_fog  fhp_score5  bti_cr  iiag_phr  fh_pr  \
# 0    Afghanistan     8.5     9.1       2          60     2.0       NaN      6
# 1        Albania     4.8     5.7       7          51     8.0       NaN      3
# 2        Algeria     6.6     6.9       3          65     5.0      41.6      6
# 3        Andorra     NaN     NaN      12          15     NaN       NaN      1
# 4         Angola     7.3     8.6       1          73     4.0      37.7      6
# ..           ...     ...     ...     ...         ...     ...       ...    ...
# 189   Uzbekistan     9.2     9.5       0          95     2.0       NaN      7
# 190    Venezuela     8.9     8.5       0          81     4.0       NaN      6
# 191        Samoa     4.1     5.5       9          29     NaN       NaN      2
# 192        Yemen     9.7     9.7       1          85     1.0       NaN      7
# 193       Zambia     7.4     7.7       6          63     5.0      58.5      4
#
# ...

# %%
correlated['cname'] = correlated['cname'].str.replace(r"\(.*\)","")

# %%
import pymysql
from sqlalchemy import create_engine
engine = create_engine('mysql+pymysql://root:******@localhost/Human Rights')
data = correlated
data.to_sql('correlated1', engine, if_exists='replace', index=False)

# %%
rulers = pd.read_csv('/Users/victoria/Project-Week6-HumanRights/REIGN_2020_9.csv')

# %%
rulers= rulers[(rulers['year']==2020)&(rulers['month']==9)]

# %%
engine = create_engine('mysql+pymysql://root:******@localhost/HumanRights')
data = rulers
data.to_sql('rulers', engine, if_exists='replace', index=False)

# %%
ruler_reign = pd.read_csv('/Users/victoria/Project-Week6-HumanRights/ruler_reign_view.csv')

# %%
ruler_reign = ruler_reign[['cname', 'ffp_hr', 'government', 'tenure_months', 'leader']]

# %%
ruler_reign['tenure_years']=ruler_reign['tenure_months']/12

# %%
ruler_reign.round(3)
# Out:
#            cname  ffp_hr               government  tenure_months  \
# 0    Afghanistan     8.5   Presidential Democracy             73
# 1        Albania     4.8  Parliamentary Democracy             85
# 2        Algeria     6.6   Provisional - Civilian             10
# 3        Andorra     NaN  Parliamentary Democracy             17
# 4         Angola     7.3           Dominant Party             37
# ..           ...     ...                      ...            ...
# 166    Venezuela     8.9    Personal Dictatorship             91
# 167      Vietnam     7.4           Dominant Party            117
# 168        Yemen     9.7               Warlordism             68
# 169       Zambia     7.4   Presidential Democracy             69
# 170     Zimbabwe     8.2           Dominant Party             35
#
#              leader  tenure_years
# 0      Ashraf Ghani         6.083
# 1              Rama         7.083
# 2          Tebboune         0.833
# 3      Espot Zamora         1.417
# ...

# %%
ruler_reign.to_csv('/Users/victoria/Project-Week6-HumanRights/ruler_reign.csv')

# %%
gdp = pd.read_csv('/Users/victoria/Project-Week6-HumanRights/countries_of_the_world.csv')

# %%
engine = create_engine('mysql+pymysql://root:******@localhost/HumanRights')
data = gdp
data.to_sql('world', engine, if_exists='replace', index=False)

# %%
time2011 = time_data[time_data['year']==2011]
time2011[['cname','gle_cgdpc']].sort_values(by='gle_cgdpc', ascending=False)
# Out:
#                   cname   gle_cgdpc
# 8575             Monaco  108481.130
# 10795             Qatar  104049.440
# 7687      Liechtenstein  102243.520
# 7095             Kuwait   64342.711
# 7835         Luxembourg   61404.480
# ...                 ...         ...
# 15309    Cyprus (-1974)         NaN
# 15383             Tibet         NaN
# 15457  Pakistan (-1970)         NaN
# 15531    Vietnam, North         NaN
# 15605    Vietnam, South         NaN
#
# [211 rows x 2 columns]

# %%
hr = pd.read_csv('/Users/victoria/Project-Week6-HumanRights/CIRI_Data.csv')

# %%
hr= hr[(hr['YEAR']==2011)]

# %%
hr.to_csv('/Users/victoria/Project-Week6-HumanRights/hr.csv')

# %%
test = correlated[['cname', 'bti_cr', 'ffp_hr']]

# %%
test = test.dropna(axis=0)

# %%
from scipy.stats import ttest_ind
#H0: Civil Rights = Human Rights
ttest_ind(test["bti_cr"], test["ffp_hr"], equal_var=False)
# Out:
# Ttest_indResult(statistic=-5.722902391545249, pvalue=2.822664994181369e-08)

# %%
import scipy
from scipy import stats
import math

hr_mean = test['ffp_hr'].mean()
hr_std = test['ffp_hr'].std()
scipy.stats.norm.interval(0.95, loc=hr_mean, scale=hr_std / math.sqrt(len(test['ffp_hr'])))
# Out:
# (6.303191448718526, 7.006438180911101)

# %%
cr = test[(test['ffp_hr']<4)]

# %%
cr.sort_values(by='ffp_hr')
# Out:
#                cname  bti_cr  ffp_hr
# 158         Slovenia     9.0     1.5
# 42        Costa Rica     9.0     1.5
# 56           Estonia    10.0     1.7
# 46    Czech Republic    10.0     2.4
# 100        Lithuania     9.0     2.5
# 156         Slovakia     9.0     2.5
# 96            Latvia     9.0     2.8
# 188          Uruguay    10.0     2.8
# 90      Korea, South     8.0     2.9
# 35             Chile     9.0     3.0
# 137           Poland     9.0     3.2
# 24          Bulgaria     8.0     3.3
# 109        Mauritius     8.0     3.4
# 43           Croatia     8.0     3.6
# 142          Romania     8.0     3.7
# 182  North Macedonia     8.0     3.8
# 118          Namibia     7.0     3.8

# %%
test["bti_cr"].corr(test["ffp_hr"])
# Out:
# -0.8919691521160675
